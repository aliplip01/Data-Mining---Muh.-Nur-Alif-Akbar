# %%
import pandas as pd

# Download the CSV file from the URL
url = "https://raw.githubusercontent.com/NathaliaMinoque/datasets/refs/heads/main/data_property_surabaya.csv"
df = pd.read_csv(url, sep=';')

df.head()
# Out:
#    ID Area Category     Nama Daerah  Luas Tanah (m2)  Luas Bangunan (m2)  \
# 0 NaN       Premium  Northwest Lake             72.0                69.0
# 1 NaN      Standard     Bukit Palma             60.0                90.0
# 2 NaN      Standard  Palma Classica            210.0               100.0
# 3 NaN      Standard     Bukit Palma            120.0                54.0
# 4 NaN      Standard     Bukit Palma             60.0                90.0
#
#    Jumlah Kamar  Jumlah Km Mandi  Tingkat/Lantai  Harga rata2 Komunitas  \
# 0             2                2             2.0             1400000000
# 1             3                2             2.0             1000000000
# 2             4                2             1.0             2400000000
# 3             3                1             1.0              800000000
# 4             3                2             2.0              800000000
#
#    Harga Dipasarkan (dari Owner)  ...  Listed Berapa Lama Pasar Sekolah  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             0 non-null      float64
#  1   Area Category                  490 non-null    object
#  2   Nama Daerah                    490 non-null    object
#  3   Luas Tanah (m2)                490 non-null    float64
#  4   Luas Bangunan (m2)             490 non-null    float64
#  5   Jumlah Kamar                   490 non-null    int64
#  6   Jumlah Km Mandi                490 non-null    int64
#  7   Tingkat/Lantai                 490 non-null    float64
#  8   Harga rata2 Komunitas          490 non-null    int64
#  9   Harga Dipasarkan (dari Owner)  490 non-null    int64
#  10  Harga Terjual                  490 non-null    int64
#  11  Terjual/Belum                  490 non-null    object
# ...

# %%
df.describe()
# Out:
#         ID  Luas Tanah (m2)  Luas Bangunan (m2)  Jumlah Kamar  \
# count  0.0       490.000000          490.000000    490.000000
# mean   NaN       210.675918          241.762245      4.197959
# std    NaN       204.131519          238.778536      2.155413
# min    NaN        35.000000           32.000000      0.000000
# 25%    NaN        96.250000          110.000000      3.000000
# 50%    NaN       155.000000          178.500000      4.000000
# 75%    NaN       240.000000          280.000000      5.000000
# max    NaN      2000.000000         2000.000000     36.000000
#
#        Jumlah Km Mandi  Tingkat/Lantai  Harga rata2 Komunitas  \
# count       490.000000      490.000000           4.900000e+02
# mean          3.265306        1.848980           4.418763e+09
# std           2.093671        0.490866           7.785302e+09
# min           1.000000        1.000000           3.000000e+08
# 25%           2.000000        2.000000           1.500000e+09
# ...

# %%
# Assuming 'id' is the name of the column you want to drop.
# If not, replace 'id' with the actual column name

df = df.drop('ID', axis=1)
df.head()
# Out:
#   Area Category     Nama Daerah  Luas Tanah (m2)  Luas Bangunan (m2)  \
# 0       Premium  Northwest Lake             72.0                69.0
# 1      Standard     Bukit Palma             60.0                90.0
# 2      Standard  Palma Classica            210.0               100.0
# 3      Standard     Bukit Palma            120.0                54.0
# 4      Standard     Bukit Palma             60.0                90.0
#
#    Jumlah Kamar  Jumlah Km Mandi  Tingkat/Lantai  Harga rata2 Komunitas  \
# 0             2                2             2.0             1400000000
# 1             3                2             2.0             1000000000
# 2             4                2             1.0             2400000000
# 3             3                1             1.0              800000000
# 4             3                2             2.0              800000000
#
#    Harga Dipasarkan (dari Owner)  Harga Terjual  ... Listed Berapa Lama Pasar  \
# ...

# %%
# Calculate null values and percentage
null_counts = df.isnull().sum()
null_percentages = (null_counts / len(df)) * 100

# Create a DataFrame for columns with null values
null_df = pd.DataFrame({'Null Count': null_counts, 'Null Percentage': null_percentages})

# Filter for columns with null values
null_df = null_df[null_df['Null Count'] > 0]


# Format the percentage with two decimal places and % symbol
null_df['Null Percentage'] = null_df['Null Percentage'].map('{:.2f}%'.format)


null_df
# Out:
#                              Null Count Null Percentage
# Pemilik Butuh Uang (Urgent)          10           2.04%
# Umur Bangunan                        44           8.98%
# Listed Berapa Lama                   45           9.18%
# Pasar                               177          36.12%
# Sekolah                             186          37.96%
# Faskes/\nRumah Sakit                237          48.37%
# Mall                                226          46.12%
# Tempat Ibadah                       202          41.22%
# Makam                               264          53.88%
# Club House                          254          51.84%
# Transportasi Umum                   265          54.08%
# Jalan Raya Utama                    247          50.41%

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create the horizontal bar plot
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')
plt.xlabel('Number of Null Values', fontsize=12)
plt.ylabel('Columns', fontsize=12)
plt.title('Null Values per Column', fontsize=14)

# Add labels to the bars
for i, v in enumerate(null_df['Null Count']):
    plt.text(v + 1, i, str(v), color='black', va='center', fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1899111875.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Null Count', y=null_df.index, data=null_df, orient='h', palette='rainbow')

# %%
# Display unique values for each column
for col in df.columns:
  print(f"Unique values for column '{col}':")
  print(df[col].unique())
  print("-" * 20)
# Out:
# Unique values for column 'Area Category':
# ['Premium' 'Standard' 'Sangat Premium' 'Below Standard']
# --------------------
# Unique values for column 'Nama Daerah':
# ['Northwest Lake' 'Bukit Palma' 'Palma Classica' 'bukit Palma' 'citraland'
#  'greenlake' 'wisata bukit mas' 'Pondok Benowo' 'Darmo' 'Sutorejo'
#  'northwest Lake' 'northwest park' 'royal park' 'selat golf'
#  'taman puspa raya' 'darmo permai' 'graha' 'grand sunrise' 'kupang indah'
#  'bayleaf' 'padmosusastro' 'pakuwon indah' 'pandugo' 'ploso' 'prapen'
#  'puri surya jaya' 'Tenggilis' 'royal residence' 'taman pondok indah'
#  'Northwest Park' 'Pelican Hill' 'Puri Widya' 'De Casa' 'Grand Pakuwon'
#  'Grand Harvest' 'Puri Safira' 'Lidah Kulon' 'Simpang' 'TWR' 'VBM'
#  'Prambanan' 'TPI' 'WBM' 'Babatan' 'Greenlake' 'northwest lake'
#  'Dukuh Kupang' 'Graha' 'pakal' 'pakuwon city' 'villa valensia'
#  'wisma lidah' 'dian istana' 'forest' 'Graha Sampurna' 'pinus asri'
# ...

# %%
# Assuming 'id' is the name of the column you want to drop.
# If not, replace 'id' with the actual column name

df = df.drop('ID', axis=1, errors='ignore')
df.head()
# Out:
#   Area Category     Nama Daerah  Luas Tanah (m2)  Luas Bangunan (m2)  \
# 0       Premium  Northwest Lake             72.0                69.0
# 1      Standard     Bukit Palma             60.0                90.0
# 2      Standard  Palma Classica            210.0               100.0
# 3      Standard     Bukit Palma            120.0                54.0
# 4      Standard     Bukit Palma             60.0                90.0
#
#    Jumlah Kamar  Jumlah Km Mandi  Tingkat/Lantai  Harga rata2 Komunitas  \
# 0             2                2             2.0             1400000000
# 1             3                2             2.0             1000000000
# 2             4                2             1.0             2400000000
# 3             3                1             1.0              800000000
# 4             3                2             2.0              800000000
#
#    Harga Dipasarkan (dari Owner)  Harga Terjual  ... Listed Berapa Lama Pasar  \
# ...

# %%
# Replace values in 'Tingkat/Lantai' column
df['Tingkat/Lantai'] = df['Tingkat/Lantai'].replace({1.5: 2, 2.5: 3, 3.5: 4, " 3.": 3})
df['Tingkat/Lantai'].unique()
# Out:
# array([2., 1., 3., 4.])

# %%
# Fill NaN values with a suitable default (e.g., 0 or the mean) or drop them
# Here we fill with 0
df['Tingkat/Lantai'] = df['Tingkat/Lantai'].fillna(0)

# Convert to integer
df['Tingkat/Lantai'] = df['Tingkat/Lantai'].astype(int)


df['Tingkat/Lantai'].unique()
# Out:
# array([2, 1, 3, 4])

# %%
# Assuming 'Pemilik Butuh Uang (Urgent)' is a categorical column
# If it's numerical, you can use a different type of histogram
plt.figure(figsize=(10, 6))  # Adjust figure size if needed
df['Pemilik Butuh Uang (Urgent)'].value_counts().plot(kind='bar')
plt.title('Bar Plot of Pemilik Butuh Uang (Urgent)')
plt.xlabel('Pemilik Butuh Uang (Urgent)')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.tight_layout() # Adjust layout to prevent labels from overlapping
plt.show()

# %%
df['Pemilik Butuh Uang (Urgent)'].fillna(df['Pemilik Butuh Uang (Urgent)'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-201075268.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Pemilik Butuh Uang (Urgent)'].fillna(df['Pemilik Butuh Uang (Urgent)'].mode()[0], inplace=True)

# %%
# prompt: Umur Bangunan barplot

# import matplotlib.pyplot as plt

# Assuming 'Umur Bangunan' is the column you want to plot
plt.figure(figsize=(10, 6))
df['Umur Bangunan'].value_counts().plot(kind='bar')
plt.title('Bar Plot of Umur Bangunan')
plt.xlabel('Umur Bangunan')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
mode_value = df['Umur Bangunan'].mode()[0]
df['Umur Bangunan'].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-325276589.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Umur Bangunan'].fillna(mode_value, inplace=True)

# %%
# Assuming 'Berapa Lama Listed' is the column you want to plot
plt.figure(figsize=(10, 6))
top_5_listed = df['Listed Berapa Lama'].value_counts().nlargest(5)
top_5_listed.plot(kind='bar')
plt.title('Top 5 Values of Listed Berapa Lama')
plt.xlabel('Berapa Lama Listed')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Fill NaN values in 'Listed Berapa Lama' with the mode
mode_listed = df['Listed Berapa Lama'].mode()[0]
df['Listed Berapa Lama'].fillna(mode_listed, inplace=True)
# Out:
# /tmp/ipython-input-2716453547.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Listed Berapa Lama'].fillna(mode_listed, inplace=True)

# %%
df['Listed Berapa Lama'].unique()
# Out:
# array(['2020', '2021', '1 bulan', '6 bln', '1 thn', '8 bln', '3 bln',
#        '4 bln', '2 bln', '5 bln', '7 bln', '1 bln', '3 thn', '2 thn',
#        '3 bulan', '6 bulan', '2 bulan', '4 bulan', '5 bulan', '1 tahun',
#        '8 bulan', '14 bulan', '7 bulan', '12 bulan', '10 bulan', '6', '2',
#        '8', '3', '4', '5', '15', '7', '18', '2 tahun', '3 tahun',
#        '<1 tahun', '< 1 tahun', '< 1tahun'], dtype=object)

# %%
# Define the mapping for 'Listed Berapa Lama'
mapping = {
    '1': ['<1 tahun', '< 1 tahun', '< 1tahun', '1 bulan', '6 bln', '1 thn', '8 bln', '3 bln',
       '4 bln', '2 bln', '2 bln ', '3 bln ', '6 bln ', '7 bln ', '1 bln ', '4 bln ',
       ' 3 bln', '3 bulan', ' 6 bulan', '6 bulan', '2 bulan', '4 bulan',
       '5 bulan', '8 bulan', '5 bln', '7 bln', '1 bln', '3 bln ', '6 bln ', '7 bln ', '1 bln ', '4 bln ', ' 3 bln',
                     '3 bulan', ' 6 bulan', '6 bulan', '2 bulan', '4 bulan', '5 bulan', '8 bulan', '14 bulan',
                     '7 bulan', '3 bulan ', '10 bulan', '6', '2', '8', '3', '4', '5', '7', '2021', '8 bulan','7 bulan', '3 bulan ', '10 bulan', '6', '2', '8', '3', '4', '5', '7'],
    '2':['2020', '12 bulan', '18', '2 tahun', '2 thn', '1 tahun', '14 bulan', '15', '18', '2 tahun'],
    '3': ['3 tahun', '3 thn']
}

# Create a new column 'Listed_Category' based on the mapping
def categorize_listed_lama(value):
    for category, values in mapping.items():
        if value in values:
            return category
    return 'Unknown'  # Handle cases where the value is not in the mapping

df['Listed Berapa Lama'] = df['Listed Berapa Lama'].apply(categorize_listed_lama)

df['Listed Berapa Lama'].unique()
# Out:
# array(['2', '1', '3'], dtype=object)

# %%
# Create a new column 'Fasilitas Publik'
df['Fasilitas Publik'] = 0

# Define the columns representing public facilities
fasilitas_columns = ['Pasar', 'Sekolah', 'Faskes/\nRumah Sakit', 'Mall', 'Tempat Ibadah', 'Makam', 'Club House', 'Transportasi Umum', 'Jalan Raya Utama']

# Iterate over the rows of the DataFrame
for index, row in df.iterrows():
  yes_count = sum(1 for col in fasilitas_columns if row[col] == 'Yes')
  if 1 <= yes_count <= 3:
    df.loc[index, 'Fasilitas Publik'] = 1
  elif 4 <= yes_count <= 6:
    df.loc[index, 'Fasilitas Publik'] = 2
  elif 7 <= yes_count <= 9:
    df.loc[index, 'Fasilitas Publik'] = 3

# Display the updated DataFrame
df.head()
# Out:
#   Area Category     Nama Daerah  Luas Tanah (m2)  Luas Bangunan (m2)  \
# 0       Premium  Northwest Lake             72.0                69.0
# 1      Standard     Bukit Palma             60.0                90.0
# 2      Standard  Palma Classica            210.0               100.0
# 3      Standard     Bukit Palma            120.0                54.0
# 4      Standard     Bukit Palma             60.0                90.0
#
#    Jumlah Kamar  Jumlah Km Mandi  Tingkat/Lantai  Harga rata2 Komunitas  \
# 0             2                2               2             1400000000
# 1             3                2               2             1000000000
# 2             4                2               1             2400000000
# 3             3                1               1              800000000
# 4             3                2               2              800000000
#
#    Harga Dipasarkan (dari Owner)  Harga Terjual  ... Pasar Sekolah  \
# ...

# %%
# Define the columns representing public facilities
fasilitas_columns = ['Pasar', 'Sekolah', 'Faskes/\nRumah Sakit', 'Mall', 'Tempat Ibadah', 'Makam', 'Club House', 'Transportasi Umum', 'Jalan Raya Utama']

# Drop the specified columns
df = df.drop(columns=fasilitas_columns, errors='ignore')

df.head()
# Out:
#   Area Category     Nama Daerah  Luas Tanah (m2)  Luas Bangunan (m2)  \
# 0       Premium  Northwest Lake             72.0                69.0
# 1      Standard     Bukit Palma             60.0                90.0
# 2      Standard  Palma Classica            210.0               100.0
# 3      Standard     Bukit Palma            120.0                54.0
# 4      Standard     Bukit Palma             60.0                90.0
#
#    Jumlah Kamar  Jumlah Km Mandi  Tingkat/Lantai  Harga rata2 Komunitas  \
# 0             2                2               2             1400000000
# 1             3                2               2             1000000000
# 2             4                2               1             2400000000
# 3             3                1               1              800000000
# 4             3                2               2              800000000
#
#    Harga Dipasarkan (dari Owner)  Harga Terjual  ...  \
# 0                     1350000000              0  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area Category                  490 non-null    object
#  1   Nama Daerah                    490 non-null    object
#  2   Luas Tanah (m2)                490 non-null    float64
#  3   Luas Bangunan (m2)             490 non-null    float64
#  4   Jumlah Kamar                   490 non-null    int64
#  5   Jumlah Km Mandi                490 non-null    int64
#  6   Tingkat/Lantai                 490 non-null    int64
#  7   Harga rata2 Komunitas          490 non-null    int64
#  8   Harga Dipasarkan (dari Owner)  490 non-null    int64
#  9   Harga Terjual                  490 non-null    int64
#  10  Terjual/Belum                  490 non-null    object
#  11  Status Kepemilikan             490 non-null    object
# ...

# %%
# Boxplot for 'Jumlah Kamar'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Kamar'])
plt.title('Boxplot of Jumlah Kamar')
plt.xlabel('Jumlah Kamar')
plt.show()

# Boxplot for 'Jumlah Kamar Mandi'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Km Mandi'])
plt.title('Boxplot of Jumlah Km Mandi')
plt.xlabel('Jumlah Km Mandi')
plt.show()

# Boxplot for 'Luas Tanah'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Tanah (m2)'])
plt.title('Luas Tanah (m2)')
plt.xlabel('Luas Tanah (m2)')
plt.show()

# Boxplot for 'Luas Bangunan'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Bangunan (m2)'])
plt.title('Luas Bangunan (m2)')
plt.xlabel('Luas Bangunan (m2)')
plt.show()

# %%
# Keep only Luas Bangunan <= 750
df = df[df['Luas Bangunan (m2)'] <= 750]

# Boxplot for 'Jumlah Kamar'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Kamar'])
plt.title('Boxplot of Jumlah Kamar')
plt.xlabel('Jumlah Kamar')
plt.show()

# Boxplot for 'Jumlah Kamar Mandi'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Km Mandi'])
plt.title('Boxplot of Jumlah Km Mandi')
plt.xlabel('Jumlah Km Mandi')
plt.show()

# Boxplot for 'Luas Tanah'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Tanah (m2)'])
plt.title('Luas Tanah (m2)')
plt.xlabel('Luas Tanah (m2)')
plt.show()

# Boxplot for 'Luas Bangunan'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Bangunan (m2)'])
plt.title('Luas Bangunan (m2)')
plt.xlabel('Luas Bangunan (m2)')
plt.show()

# %%
# Keep only Luas Tanah <= 750
df = df[df['Luas Tanah (m2)'] <= 750]

# Boxplot for 'Jumlah Kamar'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Kamar'])
plt.title('Boxplot of Jumlah Kamar')
plt.xlabel('Jumlah Kamar')
plt.show()

# Boxplot for 'Jumlah Kamar Mandi'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Km Mandi'])
plt.title('Boxplot of Jumlah Km Mandi')
plt.xlabel('Jumlah Km Mandi')
plt.show()

# Boxplot for 'Luas Tanah'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Tanah (m2)'])
plt.title('Luas Tanah (m2)')
plt.xlabel('Luas Tanah (m2)')
plt.show()

# Boxplot for 'Luas Bangunan'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Bangunan (m2)'])
plt.title('Luas Bangunan (m2)')
plt.xlabel('Luas Bangunan (m2)')
plt.show()

# %%
# Keep only Luas Tanah <= 750
df = df[df['Jumlah Km Mandi'] <= 10]

# Boxplot for 'Jumlah Kamar'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Kamar'])
plt.title('Boxplot of Jumlah Kamar')
plt.xlabel('Jumlah Kamar')
plt.show()

# Boxplot for 'Jumlah Kamar Mandi'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Jumlah Km Mandi'])
plt.title('Boxplot of Jumlah Km Mandi')
plt.xlabel('Jumlah Km Mandi')
plt.show()

# Boxplot for 'Luas Tanah'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Tanah (m2)'])
plt.title('Luas Tanah (m2)')
plt.xlabel('Luas Tanah (m2)')
plt.show()

# Boxplot for 'Luas Bangunan'
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Luas Bangunan (m2)'])
plt.title('Luas Bangunan (m2)')
plt.xlabel('Luas Bangunan (m2)')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.scatterplot(x='Luas Tanah (m2)', y='Luas Bangunan (m2)', data=df)
plt.title('Scatter Plot of Luas Tanah vs Luas Bangunan')
plt.xlabel('Luas Tanah (m2)')

plt.ylabel('Luas Bangunan (m2)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Area Category', hue='Terjual/Belum', data=df)
plt.title('Count of Properties by Area Category and Sale Status')
plt.xlabel('Area Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()
